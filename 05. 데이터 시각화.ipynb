# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(1000)
y = np.random.randn(20)
x = range(len(y))
plt.plot(x,y)

# %%
plt.plot(y) # x는 없어도 자연스럽게 y의 인덱스가 x 자리에 들어감

# %%
# 주의사항: 너무 크거나 복잡한 배열을 인수로 넣지 않도록 주의한다.
plt.plot(y.cumsum())

# %%
plt.plot(y.cumsum())
plt.grid(True)
plt.axis('tight') # option은 off, equal, scaled, tight, image, [xmin, xmax, ymin, ymax]가 있다.
# Out:
# (-0.9500000000000001, 19.95, -2.322818663749045, 0.5655085808655865)

# %%
plt.plot(y.cumsum())
plt.grid(True)
plt.xlim(-1,20)
plt.ylim(np.min(y.cumsum()) - 1, np.max(y.cumsum()) + 1)
# Out:
# (-3.1915310617211072, 1.4342209788376488)

# %%
plt.figure(figsize=(7,4))
plt.plot(y.cumsum(), 'b', lw = 1.5) # blue line
plt.plot(y.cumsum(), 'ro')  # red dot
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Random Walk')
# Out:
# Text(0.5,1,'A Random Walk')

# %%
np.random.seed(2000)
y = np.random.randn(20,2).cumsum(axis=0)

# %%
plt.figure(figsize = (7,4))
plt.plot(y, lw = 1.5)
plt.plot(y, 'ro')
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('2 Random Walks')
# Out:
# Text(0.5,1,'2 Random Walks')

# %%
plt.figure(figsize = (7,4))
plt.plot(y[:,0], lw = 1.5, label = '1st')
plt.plot(y[:,1], lw = 1.5, label = '2nd')
plt.plot(y, 'ro') # 빨간 점
plt.grid(True)
plt.legend(loc = 0) # loc = 0 이면 가려져서 보이지 않는 자료의 수가 최소화되도록 최적의 범례위치를 자동으로 잡아준다.
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('2 Random Walks')
# Out:
# Text(0.5,1,'2 Random Walks')

# %% [markdown]
# #### 크기가 전혀 다른 여러개의 자료를 그릴 때는 하나의 y축만 써서는 시각적 정보를 제대로 표시하기 힘들다.

# %%
y[:, 1] = y[:, 0] * 100
plt.figure(figsize=(7, 4))
plt.plot(y[:,0], lw = 1.5, label = '1st')
plt.plot(y[:,1], lw = 1.5, label = '2nd')
plt.plot(y, 'ro') # 빨간 점
plt.grid(True)
plt.legend(loc = 0) # loc = 0 이면 가려져서 보이지 않는 자료의 수가 최소화되도록 최적의 범례위치를 자동으로 잡아준다.
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('2 Random Walks')
print('1st 자료가 거의 직선이므로 해당 정보가 시각적으로 손실되었다.')
# Out:
# 1st 자료가 거의 직선이므로 해당 정보가 시각적으로 손실되었다.

# %%
fig, ax1 = plt.subplots()
plt.plot(y[:, 0], 'b', lw=1.5, label='1st')
plt.plot(y[:, 0], 'ro')
plt.grid(True)
plt.legend(loc=8)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value 1st')
plt.title('A Simple Plot')
ax2 = ax1.twinx()
plt.plot(y[:, 1], 'g', lw=1.5, label='2nd')
plt.plot(y[:, 1], 'ro')
plt.legend(loc=0)
plt.ylabel('value 2nd')
# Out:
# Text(0,0.5,'value 2nd')

# %%
plt.figure(figsize=(7,5))

plt.subplot(211) # nrow, ncol,fignum을 인수로. 쉼표로 분리하지 않아도 괜찮다.
plt.plot(y[:, 0], lw=1.5, label='1st')
plt.plot(y[:, 0], 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
plt.title('A Simple Plot')

plt.subplot(212) # 행 2개 열 1개 짜리 플롯에서 2행에 있는 플롯
plt.plot(y[:, 1], 'g', lw=1.5, label='2nd')
plt.plot(y[:, 1], 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
# Out:
# Text(0,0.5,'value')

# %%
plt.figure(figsize=(9, 4))
plt.subplot(121)
plt.plot(y[:,0], lw = 1.5, label = '1st')
plt.plot(y[:,0], 'ro')
plt.grid(True)
plt.legend(loc = 0)
plt.axis("tight")
plt.xlabel("index")
plt.ylabel("value")
plt.title("1st Data Set")

plt.subplot(122)
plt.bar(np.arange(len(y)), y[:, 1], width = 0.5,
       color = 'g', label = '2nd')
plt.grid(True)
plt.legend(loc = 0)
plt.axis('tight')
plt.xlabel('index')
plt.title('2nd Data Set')
# Out:
# Text(0.5,1,'2nd Data Set')

# %%
y = np.random.randn(1000, 2)
plt.figure(figsize = (7, 5))
plt.plot(y[:,0], y[:, 1], 'ro')
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5,1,'Scatter Plot')

# %%
plt.figure(figsize = (7,5))
plt.scatter(y[:, 0], y[:, 1], marker = 'o')
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5,1,'Scatter Plot')

# %%
c = np.random.randint(0,10, len(y)) # 0 이상 10 미만의 정수인 난수를 len(y)개 생성.
plt.figure(figsize = (7,5))
plt.scatter(y[:, 0], y[:, 1], c = c ,marker = 'o' )
plt.colorbar()
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter Plot')
# Out:
# Text(0.5,1,'Scatter Plot')

# %%
plt.figure(figsize=(7, 4))
plt.hist(y, label=['1st', '2nd'], bins = 25) # label로 사용되는 문자열 지정
plt.grid(True)
plt.axis('tight')
plt.legend(loc=0)
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('Histogram')
# Out:
# Text(0.5,1,'Histogram')

# %%
plt.figure(figsize = (7,4))
plt.hist(y, label=['1st', '2nd'], color = ['b', 'g'], 
        stacked=True, bins = 20)
plt.grid(True)
plt.legend(loc=0)
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('Histogram')
# Out:
# Text(0.5,1,'Histogram')

# %%
fig, ax = plt.subplots(figsize=(7,4))
plt.boxplot(y)
plt.grid(True)
#plt.setp(ax, xticklabels=['1st', '2nd'])
plt.xlabel('data set')
plt.ylabel('value')
plt.title('Boxplot')
# Out:
# Text(0.5,1,'Boxplot')

# %%
from matplotlib.patches import Polygon
def func(x):
    return 0.5 * np.exp(x) + 1
a, b = 0.5, 1.5 # 적분구간
x = np.linspace(0,2)
y = func(x)

fig, ax = plt.subplots(figsize=(7,5))
plt.plot(x, y, 'b', linewidth = 2)
plt.ylim(ymin = 0)

Ix = np.linspace(a,b)
Iy = func(Ix)
verts = [(a,0)] + list(zip(Ix, Iy)) + [(b,0)]
poly = Polygon(verts, facecolor='0.7', edgecolor='0.4')
ax.add_patch(poly)

plt.text(0.5 * (a + b), 1, r"$\int_a^b f(x)\mathrm{d}x$", # LATEX. 인테그랄 표시
        horizontalalignment='center', fontsize=20)
plt.figtext(0.9,0.075, '$x$')
plt.figtext(0.075,0.9, '$f(x)$')

ax.set_xticks((a,b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([func(a), func(b)])
ax.set_yticklabels(('$f(a)$', '$f(b)$'))
plt.grid(True)

# %% [markdown]
# ## Financial Plots

# %%
import pandas as pd
import cufflinks as cf
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:558: DeprecationWarning:
#
# plotly.graph_objs.YAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.YAxis
#   - plotly.graph_objs.layout.scene.YAxis
#
#
# C:\ProgramData\Miniconda3\lib\site-packages\plotly\graph_objs\_deprecations.py:531: DeprecationWarning:
#
# plotly.graph_objs.XAxis is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.XAxis
#   - plotly.graph_objs.layout.scene.XAxis

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
raw = pd.read_csv('source/fxcm_eur_usd_eod_data.csv', index_col = 0,
                 parse_dates = True)
raw.columns
# Out:
# Index(['Time', 'OpenBid', 'HighBid', 'LowBid', 'CloseBid', 'OpenAsk',
#        'HighAsk', 'LowAsk', 'CloseAsk', 'TotalTicks'],
#       dtype='object')

# %%
quotes = raw[['OpenAsk', 'HighAsk', 'LowAsk', 'CloseAsk']]
quotes.columns
# Out:
# Index(['OpenAsk', 'HighAsk', 'LowAsk', 'CloseAsk'], dtype='object')

# %%
qf = cf.QuantFig(quotes.iloc[-100:], title='EUR/USD', legend='top',
                 name='EUR/USD', datalegend=False)

# %%
iplot(qf.iplot(asFigure=True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-ede139723b0c> in <module>()
# ----> 1 iplot(qf.iplot(asFigure=True))
#
# C:\ProgramData\Miniconda3\lib\site-packages\cufflinks\quant_figure.py in iplot(self, **kwargs)
#    1184                 d=utils.deep_update(d,kwargs)
#    1185                 d=tools.updateColors(d)
# -> 1186                 fig=df.figure(**d)
#    1187                 if d['kind'] not in ('candle','candlestick','ohlc'):
#    1188                         fig.move_axis(yaxis='y2')
#
# C:\ProgramData\Miniconda3\lib\site-packages\cufflinks\plotlytools.py in _figure(self, **kwargs)
#    1222 	"""
#    1223         kwargs['asFigure']=True
# -> 1224         return self.iplot(**kwargs)
#    1225
#    1226 def _layout(self,**kwargs):
#
# ...

# %% [markdown]
# ## 3d Plotting

# %%
strike = np.linspace(50, 150, 24)
ttm = np.linspace(0.5, 2.5, 24)
strike, ttm = np.meshgrid(strike, ttm)

# %%
len(strike)
# Out:
# 24

# %%
# generate fake implied volatilities
iv = (strike - 100) ** 2/ (100 * strike) / ttm

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(9, 6))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(strike, ttm, iv, rstride=2, cstride=2,
                       cmap=plt.cm.coolwarm, linewidth=0.5,
                       antialiased=True)

ax.set_xlabel('strike')
ax.set_ylabel('time-to-maturity')
ax.set_zlabel('implied volatility')

fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(111, projection='3d')
ax.view_init(30, 60)

ax.scatter(strike, ttm, iv, zdir='z', s=25,
           c='b', marker='^')

ax.set_xlabel('strike')
ax.set_ylabel('time-to-maturity')
ax.set_zlabel('implied volatility')

# tag: matplotlib_18
# title: 3d scatter plot for (fake) implied volatilities
# size: 70
# Out:
# Text(0.5,0,'implied volatility')
